# %%
import pandas as pd
web = 'https://resultados.as.com/resultados/futbol/primera/clasificacion/'
df = pd.read_html(web)
df[2]
# Out:
#              Equipo  Pts.  PJ  PG  PE  PP  GF  GC
# 0    1  Real Madrid    41  17  13   2   2  35  16
# 1      2  Barcelona    31  17   8   7   2  29  18
# 2        3  Sevilla    26  17   6   8   3  15  11
# 3       4  Atlético    24  16   7   3   6  28  24
# 4          5  Betis    28  16   8   4   4  25  18
# 5    6  R. Sociedad    23  16   6   5   5  20  24
# 6     7  Villarreal    17  16   4   5   7  15  16
# 7       8  Athletic    21  17   4   9   4  14  16
# 8        9  Osasuna    23  16   7   2   7  18  21
# 9      10  Valencia    20  17   5   5   7  21  28
# 10      11  Rayo  3    12  17   3   3  11  12  26
# 11     12  Celta  1    20  16   5   5   6  15  14
# 12  13  Espanyol  1     8  16   1   5  10  14  28
# 13     14  Elche  1    15  17   4   3  10  16  27
# 14       15  Getafe    10  17   1   7   9  10  22
# 15  16  Mallorca  2     8  16   2   2  12  13  36
# 16     17  Cádiz  1    17  16   4   5   7  14  23
# 17   18  Granada  1    13  17   2   7   8  16  28
# ...

# %%
df = pd.read_excel('siniestros.xls')
df.head()
# Out:
#    Poliza  Importe
# 0  102541       17
# 1  101204       20
# 2  104459       22
# 3  102976       10
# 4  105099       16

# %%
filename = 'EIOPA_RFR_20220331_Term_Structures.xlsx'
sheetname = 'RFR_spot_no_VA'
clr = pd.read_excel(filename, sheet_name=sheetname, skiprows=9, usecols=(1,2), names=['t','Euro'])
clr.head()
# Out:
#    t     Euro
# 0  1 -0.00175
# 1  2  0.00436
# 2  3  0.00703
# 3  4  0.00829
# 4  5  0.00895

# %%
web2 = 'https://www.bolsamadrid.es/esp/aspx/Mercados/Precios.aspx?indice=ESI100000000'
df2 = pd.read_html(web2)[3]
df2['Últ.'] = df2['Últ.']/10000
df2
# Out:
#           Nombre      Últ.  % Dif.     Máx.     Mín.     Volumen  \
# 0        ACCIONA  190.2000     -78  1920000  1895000      14.146
# 1       ACERINOX   10.0300      93   101150   100050     304.473
# 2            ACS   24.8800      12   250000   248100      85.702
# 3           AENA  136.2500    -212  1423000  1350500      32.143
# 4       ALMIRALL   12.4500     -16   125300   123200      69.127
# 5        AMADEUS   60.6000     171   610600   601600      97.775
# 6    ARCELORMIT.   28.0600     117   285900   280100     214.048
# 7    B.SANTANDER    2.7965     162    28100    27610  40.244.584
# 8    BA.SABADELL    0.7434     305     7454     7160  12.014.274
# 9      BANKINTER    5.5640      69    55720    54700     507.820
# 10          BBVA    4.9645     456    50130    48600   6.770.161
# 11     CAIXABANK    3.0500     290    30590    29130   9.531.778
# 12       CELLNEX   44.4400      43   451000   439700     162.307
# ...
