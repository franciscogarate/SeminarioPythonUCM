# %% [markdown]
# # Sesión 1. Autoevalución

# %% [markdown]
# ## Funciones
# <pre>
# A. 101
# B. 1
# C. 100
# D. Error
# </pre>

# %%
def f1():
    x = 100
    return x

x = f1() + 1
#x

# %% [markdown]
# ## Funciones 2
# <pre>
# A. [2, 3, 4]
# B. [1, 2, 3, 4]
# C. [1, 3, 4]
# D. Ninguno de los anteriores
# </pre>

# %%
def f2(values):
    values[0] = 1

x = [2, 3, 4]
f2(x) 
#x

# %% [markdown]
# ## listado
# <pre>
# A. Error
# B. [0, 1, 2, 3, 4, 7, 6]
# C. [7, 0, 1, 2, 3, 4, 5, 6]
# D. [0, 1, 2, 3, 4, 5, 7]

# %%
x = [0, 1, 2, 3, 4, 5, 6]
x[-1] = 7
#x

# %% [markdown]
# ## listado
# <pre>
# A. Error
# B. [0, 9, 9, 9, 9, 9, 9]
# C. [0, 9, 6]
# D. [0, 9, 9, 9, 9, 9, 6]

# %%
x = [0, 1, 2, 3, 4, 5, 6]
x[1:-1] = [9]
#x
