# %%
import pandas as pd
import numpy as np

df= pd.DataFrame([1,3,6,8,9], columns=['Datos'])
df
# Out:
#    Datos
# 0      1
# 1      3
# 2      6
# 3      8
# 4      9

# %%
df.plot()
# Out:
# <AxesSubplot:>

# %%
import matplotlib.pyplot as plt

x = [1,2,3,4,5,6]
y = [0.15, 1, 3, 16,18,45]
#plt.scatter(x,y)
plt.plot(x,y)

# %%
x = np.linspace(0,8,50)
y = np.sin(x)
plt.plot(x,y)
