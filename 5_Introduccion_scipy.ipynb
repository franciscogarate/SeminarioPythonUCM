# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
# random.normal(loc=0.0, scale=1.0, size=None)
df = pd.DataFrame(np.random.normal(4,1,10000))
df.hist(bins=50)
# Out:
# array([[<AxesSubplot:title={'center':'0'}>]], dtype=object)

# %%
import scipy.stats as st

# %%
distr_normal = st.norm(4,1)
distr_normal

# %%
distr_normal.pdf(2)
# Out:
# 0.05399096651318806

# %%
x = np.linspace(0,8,100)
y = distr_normal.pdf(x)
plt.plot(x,y)
