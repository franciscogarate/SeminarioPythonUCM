# %% [markdown]
# # Ejemplo ajuste a una distribución

# %%
import matplotlib.pyplot as plt
import scipy.stats as st
import numpy as np
import warnings
warnings.filterwarnings('ignore')

plt.style.use('seaborn')
# Creo 10.000 números aleatorios siguiendo una lognormal
size = 10000
np.random.seed(999)
x = np.arange(size)
y = np.random.lognormal(np.log(10), np.log(2), size)

# Ajusto los datos aleatorios a las siguientes distribuciones:
distrs = ['rayleigh', 'norm', 'lognorm', 'gamma', 'beta', 'exponweib', 'invweibull']
for i in distrs:
    dist = getattr(st, i)
    param = dist.fit(y)
    pdf_fitted = dist.pdf(x, *param[:-2], loc=param[-2], scale=param[-1]) * size
    plt.plot(pdf_fitted, label=i)
    plt.xlim(0,35)
plt.hist(y, bins=range(50), alpha=0.75)
plt.legend(loc='upper right')
plt.show()
